# %% [markdown]
# #### Example: WebSearch as a Tool
# 1) Prompt -> LLM.
# 2) LLM decides a web search is needed.
# 3) Call WebSearch tool
# 4) Augment user's prompt with search results
# 5) Generate answer

# %%
from dotenv import load_dotenv
import os
from tavily import TavilyClient
from typing import List
import dspy

load_dotenv()
# Out:
# True

# %%
tavily_client = TavilyClient(api_key=os.getenv('TAVILY_API_KEY'))

def fetch_recent_news(query: str) -> List[str]:
    """
    Inputs a query string, searches for news, and returns the top results.
    """
    
    response = tavily_client.search(query=query, topic='news', max_results=4)
    return [
        x['content']
        for x in response['results']
    ]

class HaikuGenerator(dspy.Signature):
    """Generates a haiku about the latest news on the query."""
    query = dspy.InputField()
    summary = dspy.OutputField(desc='A summary of the latest news.')
    haiku = dspy.OutputField()

# %%
program = dspy.ReAct(
    signature=HaikuGenerator,
    tools=[fetch_recent_news],
    max_iters=1,  # number of tool calls that the LLM can make
)
program.set_lm(dspy.LM('gemini/gemini-2.5-flash-lite', temperature=0.7))
pred = program(query='OpenAI')

# %%
print(pred.summary)
print()
print(pred.haiku)
# Out:
# Recent news about OpenAI includes Elon Musk's lawsuit alleging a violation of its founding mission, which will proceed to trial. The company is also reportedly developing a new voice AI model and devices, and has launched ChatGPT Health, a feature for analyzing medical test results and offering health advice.
#
# Musk's suit goes to trial,
# Voice AI, health insights bloom,
# Future takes new form.

# %%
print(program.inspect_history(n=4))
# Out:
# [2026-01-08T13:57:25.587793]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# 2. `trajectory` (str):
# Your output fields are:
# 1. `next_thought` (str):
# 2. `next_tool_name` (Literal['fetch_recent_news', 'finish']):
# 3. `next_tool_args` (dict[str, Any]):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## next_thought ## ]]
# {next_thought}
#
# [[ ## next_tool_name ## ]]
# {next_tool_name}        # note: the value you produce must exactly match (no extra characters) one of: fetch_recent_news; finish
#
# [[ ## next_tool_args ## ]]
# {next_tool_args}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generates a haiku about the latest news on the query.
#
#         You are an Agent. In each episode, you will be given the fields `query` as input. And you can see your past trajectory so far.
#         Your goal is to use one or more of the supplied tools to collect any necessary information for producing `summary`, `haiku`.
#
#         To do this, you will interleave next_thought, next_tool_name, and next_tool_args in each turn, and also when finishing the task.
#         After each tool call, you receive a resulting observation, which gets appended to your trajectory.
#
#         When writing next_thought, you may reason about the current situation and plan for future steps.
#         When selecting the next_tool_name and its next_tool_args, the tool must be one of:
#
#         (1) fetch_recent_news, whose description is <desc>      Inputs a query string, searches for news, and returns the top results.      </desc>. It takes arguments {'query': {'type': 'string'}}.
#         (2) finish, whose description is <desc>Marks the task as complete. That is, signals that all information for producing the outputs, i.e. `summary`, `haiku`, are now available to be extracted.</desc>. It takes arguments {}.
#         When providing `next_tool_args`, the value inside the field must be in JSON format
#
#
# User message:
#
# [[ ## query ## ]]
# OpenAI
#
# [[ ## trajectory ## ]]
#
#
# Respond with the corresponding output fields, starting with the field `[[ ## next_thought ## ]]`, then `[[ ## next_tool_name ## ]]` (must be formatted as a valid Python Literal['fetch_recent_news', 'finish']), then `[[ ## next_tool_args ## ]]` (must be formatted as a valid Python dict[str, Any]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## next_thought ## ]]
# The user is asking for a haiku about the latest news on OpenAI. To fulfill this request, I need to fetch recent news about OpenAI. The `fetch_recent_news` tool seems appropriate for this. I will use "OpenAI" as the query for the tool.
#
# [[ ## next_tool_name ## ]]
# fetch_recent_news
#
# [[ ## next_tool_args ## ]]
# {"query": "OpenAI"}
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-08T13:57:28.035317]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# 2. `trajectory` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `summary` (str): A summary of the latest news.
# 3. `haiku` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## summary ## ]]
# {summary}
#
# [[ ## haiku ## ]]
# {haiku}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generates a haiku about the latest news on the query.
#
#
# User message:
#
# [[ ## query ## ]]
# OpenAI
#
# [[ ## trajectory ## ]]
# [[ ## thought_0 ## ]]
# The user is asking for a haiku about the latest news on OpenAI. To fulfill this request, I need to fetch recent news about OpenAI. The `fetch_recent_news` tool seems appropriate for this. I will use "OpenAI" as the query for the tool.
#
# [[ ## tool_name_0 ## ]]
# fetch_recent_news
#
# [[ ## tool_args_0 ## ]]
# {"query": "OpenAI"}
#
# [[ ## observation_0 ## ]]
# [1] «# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk's lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".»
# [2] «# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.»
# [3] «# 'This case is going to trial': Judge rejects Sam Altman's efforts to toss Elon Musk's OpenAI lawsuit. * A California judge said that Elon Musk's lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman's lawyers' last-ditch efforts to end Musk's case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk's ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company's structure.»
# [4] «# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routines — marking the company’s biggest push yet into the healthcare sector. OpenAI unveils ChatGPT Health to review test results, diets. More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI unveils ChatGPT Health to review test results, diets. ## See More in AI. OpenAI unveils ChatGPT Health to review test results, diets. AI Tracker: 40 million use ChatGPT daily for healthcare. Beyond the hype: AI that delivers in healthcare. Investors, founders fear an AI bubble in healthcare.»
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## summary ## ]]`, then `[[ ## haiku ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The user wants a haiku about the latest news on OpenAI. I have fetched several recent news articles about OpenAI. The most prominent themes are:
# 1. Elon Musk's lawsuit against OpenAI proceeding to trial, alleging a violation of its founding mission.
# 2. OpenAI's development of a new voice AI model and potentially new voice-based AI devices.
# 3. OpenAI unveiling ChatGPT Health, a feature to analyze medical test results and provide health guidance.
#
# I will synthesize these points into a haiku.
#
# [[ ## summary ## ]]
# Recent news about OpenAI includes Elon Musk's lawsuit alleging a violation of its founding mission, which will proceed to trial. The company is also reportedly developing a new voice AI model and devices, and has launched ChatGPT Health, a feature for analyzing medical test results and offering health advice.
#
# [[ ## haiku ## ]]
# Musk's suit goes to trial,
# Voice AI, health insights bloom,
# Future takes new form.
#
# [[ ## completed ## ]]
#
#
#
#
#
# None

# %% [markdown]
# Key fragment:
# ```ini
# [[ ## next_tool_name ## ]]
# fetch_recent_news
#
# [[ ## next_tool_args ## ]]
# {"query": "OpenAI"}
#
# ```

# %% [markdown]
# MCP Servers
# - Not covered here.
# - Standardized protocol of providing context and tools to LLMs.
#
# Popularity of Tools
# - Tools in Gemini CLI: `ReadFolder`, `ReadFile`, `SearchText`, `FindFiles`, `Edit`, `WriteFile`, `WebFetch`, `ReadManyFiles`, `Shell`, `SaveMemory`, `GoogleSearch`

# %% [markdown]
# ### WriteFile example

# %%
class HaikuGenerator(dspy.Signature):
    """
    Generates a haiku about the latest news on the query.
    Saves the final summary in a file.
    """
    query = dspy.InputField()
    summary = dspy.OutputField(desc='A summary of the latest news.')
    haiku = dspy.OutputField()

def write_file(text: str, filename: str):
    """Write text into a file."""
    with open(filename,'w') as f:
        f.write(text)

# %%
program = dspy.ReAct(
    signature=HaikuGenerator,
    tools=[fetch_recent_news, write_file],
    max_iters=2,  # need to increase this so it can call 2 tools
)
program.set_lm(dspy.LM('gemini/gemini-2.5-flash-lite', temperature=0.7))
pred = program(query='OpenAI')

# %%
print(pred.summary)
# Out:
# Recent news about OpenAI includes a lawsuit filed by Elon Musk, alleging the company violated its founding mission by becoming a for-profit entity. A judge has allowed this case to proceed to trial. Additionally, OpenAI is reportedly developing a new voice AI model for voice-based devices, with plans to potentially ship millions of units. The company has also launched ChatGPT Health, a new feature allowing users to analyze medical test results, get dietary advice, and prepare for doctor's appointments, marking a significant expansion into the healthcare sector.

# %%
program.inspect_history(n=4)
# Out:
# [2026-01-08T14:11:05.101507]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# 2. `trajectory` (str):
# Your output fields are:
# 1. `next_thought` (str):
# 2. `next_tool_name` (Literal['fetch_recent_news', 'write_file', 'finish']):
# 3. `next_tool_args` (dict[str, Any]):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## next_thought ## ]]
# {next_thought}
#
# [[ ## next_tool_name ## ]]
# {next_tool_name}        # note: the value you produce must exactly match (no extra characters) one of: fetch_recent_news; write_file; finish
#
# [[ ## next_tool_args ## ]]
# {next_tool_args}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generates a haiku about the latest news on the query.
#         Saves the final summary in a file.
#
#         You are an Agent. In each episode, you will be given the fields `query` as input. And you can see your past trajectory so far.
#         Your goal is to use one or more of the supplied tools to collect any necessary information for producing `summary`, `haiku`.
#
#         To do this, you will interleave next_thought, next_tool_name, and next_tool_args in each turn, and also when finishing the task.
#         After each tool call, you receive a resulting observation, which gets appended to your trajectory.
#
#         When writing next_thought, you may reason about the current situation and plan for future steps.
#         When selecting the next_tool_name and its next_tool_args, the tool must be one of:
#
#         (1) fetch_recent_news, whose description is <desc>      Inputs a query string, searches for news, and returns the top results.      </desc>. It takes arguments {'query': {'type': 'string'}}.
#         (2) write_file, whose description is <desc>Write text into a file.</desc>. It takes arguments {'text': {'type': 'string'}, 'filename': {'type': 'string'}}.
#         (3) finish, whose description is <desc>Marks the task as complete. That is, signals that all information for producing the outputs, i.e. `summary`, `haiku`, are now available to be extracted.</desc>. It takes arguments {}.
#         When providing `next_tool_args`, the value inside the field must be in JSON format
#
#
# User message:
#
# [[ ## query ## ]]
# OpenAI
#
# [[ ## trajectory ## ]]
#
#
# Respond with the corresponding output fields, starting with the field `[[ ## next_thought ## ]]`, then `[[ ## next_tool_name ## ]]` (must be formatted as a valid Python Literal['fetch_recent_news', 'write_file', 'finish']), then `[[ ## next_tool_args ## ]]` (must be formatted as a valid Python dict[str, Any]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## next_thought ## ]]
# I need to find the latest news about OpenAI to write a haiku. The `fetch_recent_news` tool seems appropriate for this.
# [[ ## next_tool_name ## ]]
# fetch_recent_news
# [[ ## next_tool_args ## ]]
# {"query": "OpenAI"}
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-08T14:11:07.505710]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# 2. `trajectory` (str):
# Your output fields are:
# 1. `next_thought` (str):
# 2. `next_tool_name` (Literal['fetch_recent_news', 'write_file', 'finish']):
# 3. `next_tool_args` (dict[str, Any]):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## next_thought ## ]]
# {next_thought}
#
# [[ ## next_tool_name ## ]]
# {next_tool_name}        # note: the value you produce must exactly match (no extra characters) one of: fetch_recent_news; write_file; finish
#
# [[ ## next_tool_args ## ]]
# {next_tool_args}        # note: the value you produce must adhere to the JSON schema: {"type": "object", "additionalProperties": true}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generates a haiku about the latest news on the query.
#         Saves the final summary in a file.
#
#         You are an Agent. In each episode, you will be given the fields `query` as input. And you can see your past trajectory so far.
#         Your goal is to use one or more of the supplied tools to collect any necessary information for producing `summary`, `haiku`.
#
#         To do this, you will interleave next_thought, next_tool_name, and next_tool_args in each turn, and also when finishing the task.
#         After each tool call, you receive a resulting observation, which gets appended to your trajectory.
#
#         When writing next_thought, you may reason about the current situation and plan for future steps.
#         When selecting the next_tool_name and its next_tool_args, the tool must be one of:
#
#         (1) fetch_recent_news, whose description is <desc>      Inputs a query string, searches for news, and returns the top results.      </desc>. It takes arguments {'query': {'type': 'string'}}.
#         (2) write_file, whose description is <desc>Write text into a file.</desc>. It takes arguments {'text': {'type': 'string'}, 'filename': {'type': 'string'}}.
#         (3) finish, whose description is <desc>Marks the task as complete. That is, signals that all information for producing the outputs, i.e. `summary`, `haiku`, are now available to be extracted.</desc>. It takes arguments {}.
#         When providing `next_tool_args`, the value inside the field must be in JSON format
#
#
# User message:
#
# [[ ## query ## ]]
# OpenAI
#
# [[ ## trajectory ## ]]
# [[ ## thought_0 ## ]]
# I need to find the latest news about OpenAI to write a haiku. The `fetch_recent_news` tool seems appropriate for this.
#
# [[ ## tool_name_0 ## ]]
# fetch_recent_news
#
# [[ ## tool_args_0 ## ]]
# {"query": "OpenAI"}
#
# [[ ## observation_0 ## ]]
# [1] «# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk's lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".»
# [2] «# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.»
# [3] «# 'This case is going to trial': Judge rejects Sam Altman's efforts to toss Elon Musk's OpenAI lawsuit. * A California judge said that Elon Musk's lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman's lawyers' last-ditch efforts to end Musk's case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk's ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company's structure.»
# [4] «# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routines — marking the company’s biggest push yet into the healthcare sector. OpenAI unveils ChatGPT Health to review test results, diets. More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI unveils ChatGPT Health to review test results, diets. ## See More in AI. OpenAI unveils ChatGPT Health to review test results, diets. AI Tracker: 40 million use ChatGPT daily for healthcare. Beyond the hype: AI that delivers in healthcare. Investors, founders fear an AI bubble in healthcare.»
#
# Respond with the corresponding output fields, starting with the field `[[ ## next_thought ## ]]`, then `[[ ## next_tool_name ## ]]` (must be formatted as a valid Python Literal['fetch_recent_news', 'write_file', 'finish']), then `[[ ## next_tool_args ## ]]` (must be formatted as a valid Python dict[str, Any]), and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## next_thought ## ]]
# I have fetched the latest news about OpenAI. Now I need to synthesize this information into a haiku and then write it to a file. The news covers a lawsuit by Elon Musk, development of new voice AI models, and a new healthcare feature for ChatGPT.
#
# Here's a draft for the haiku:
# Musk sues OpenAI,
# Voice AI and health now emerge,
# Future takes new shape.
#
# Now I will use the `write_file` tool to save this haiku.
#
# [[ ## next_tool_name ## ]]
# write_file
#
# [[ ## next_tool_args ## ]]
# {"filename": "openai_haiku.txt", "text": "Musk sues OpenAI,\nVoice AI and health now emerge,\nFuture takes new shape."}
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2026-01-08T14:11:09.595090]
#
# System message:
#
# Your input fields are:
# 1. `query` (str):
# 2. `trajectory` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `summary` (str): A summary of the latest news.
# 3. `haiku` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## query ## ]]
# {query}
#
# [[ ## trajectory ## ]]
# {trajectory}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## summary ## ]]
# {summary}
#
# [[ ## haiku ## ]]
# {haiku}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generates a haiku about the latest news on the query.
#         Saves the final summary in a file.
#
#
# User message:
#
# [[ ## query ## ]]
# OpenAI
#
# [[ ## trajectory ## ]]
# [[ ## thought_0 ## ]]
# I need to find the latest news about OpenAI to write a haiku. The `fetch_recent_news` tool seems appropriate for this.
#
# [[ ## tool_name_0 ## ]]
# fetch_recent_news
#
# [[ ## tool_args_0 ## ]]
# {"query": "OpenAI"}
#
# [[ ## observation_0 ## ]]
# [1] «# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk's lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".»
# [2] «# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.»
# [3] «# 'This case is going to trial': Judge rejects Sam Altman's efforts to toss Elon Musk's OpenAI lawsuit. * A California judge said that Elon Musk's lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman's lawyers' last-ditch efforts to end Musk's case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk's lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk's ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company's structure.»
# [4] «# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routines — marking the company’s biggest push yet into the healthcare sector. OpenAI unveils ChatGPT Health to review test results, diets. More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI unveils ChatGPT Health to review test results, diets. ## See More in AI. OpenAI unveils ChatGPT Health to review test results, diets. AI Tracker: 40 million use ChatGPT daily for healthcare. Beyond the hype: AI that delivers in healthcare. Investors, founders fear an AI bubble in healthcare.»
#
# [[ ## thought_1 ## ]]
# I have fetched the latest news about OpenAI. Now I need to synthesize this information into a haiku and then write it to a file. The news covers a lawsuit by Elon Musk, development of new voice AI models, and a new healthcare feature for ChatGPT.
#
# Here's a draft for the haiku:
# Musk sues OpenAI,
# Voice AI and health now emerge,
# Future takes new shape.
#
# Now I will use the `write_file` tool to save this haiku.
#
# [[ ## tool_name_1 ## ]]
# write_file
#
# [[ ## tool_args_1 ## ]]
# {"filename": "openai_haiku.txt", "text": "Musk sues OpenAI,\nVoice AI and health now emerge,\nFuture takes new shape."}
#
# [[ ## observation_1 ## ]]
# None
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## summary ## ]]`, then `[[ ## haiku ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# The user wants a haiku about the latest news on OpenAI. I have already fetched the news and drafted a haiku. Now I need to provide the reasoning, summary, and haiku in the specified format, and then mark the task as completed.
#
# [[ ## summary ## ]]
# Recent news about OpenAI includes a lawsuit filed by Elon Musk, alleging the company violated its founding mission by becoming a for-profit entity. A judge has allowed this case to proceed to trial. Additionally, OpenAI is reportedly developing a new voice AI model for voice-based devices, with plans to potentially ship millions of units. The company has also launched ChatGPT Health, a new feature allowing users to analyze medical test results, get dietary advice, and prepare for doctor's appointments, marking a significant expansion into the healthcare sector.
#
# [[ ## haiku ## ]]
# Musk sues OpenAI,
# Voice AI and health now emerge,
# Future takes new shape.
#
# [[ ## completed ## ]]

# %% [markdown]
# ### JokeGenerator example

# %%
import asyncio
from typing import Optional
from pydantic import BaseModel, Field

# %%
class JokeIdea(BaseModel):
    setup: str
    contradiction: str
    punchline: str

class QueryToIdea(dspy.Signature):
    """You are a funny comedian and your goal is to generate a nice structure for a joke."""
    query: str = dspy.InputField()
    joke_idea: JokeIdea = dspy.OutputField()

class IdeaToJoke(dspy.Signature):
    """
    You are a funny comedian who likes to tell stories before delivering a punchline.
    You are always funny and act on the input joke idea.
    If you are provided a draft of a joke, your goal should be to make it funnier and punchy.
    """
    joke_idea: JokeIdea = dspy.InputField()
    joke_draft: Optional[str] = dspy.InputField(description='An existing joke that you need to either refine or change.')
    joke: str = dspy.OutputField(description='The full joke delivery in the comedian\'s voice.')

class JokeJudge(dspy.Signature):
    """Rank each joke idea between 1 to N. Rank 1 is the most unique and funniest."""
    joke_idea: List[JokeIdea] = dspy.InputField()
    joke_ratings: List[int] = dspy.OutputField(description='Rank between 1, 2, 3, ..., N')

def check_score_goodness(args, pred):
    n_samples = len(args['joke_idea'])
    same_len = len(pred.joke_ratings) == n_samples
    all_ranks_present = all([
        (i+1) in pred.joke_ratings
        for i in range(n_samples)
    ])
    return 1 if (same_len and all_ranks_present) else 0

# %%
class IdeaGenerator(dspy.Module):
    def __init__(self, n_samples=3):
        # only need to replace ChainOfThought with ReAct and pass the tools
        self.query2idea = dspy.ReAct(
            QueryToIdea,
            [fetch_recent_news],
            1
        )
        self.query2idea.set_lm(dspy.LM('gemini/gemini-2.5-flash-lite', temperature=1))
        
        self.judge = dspy.Refine(dspy.ChainOfThought(JokeJudge),
                                 N=3, reward_fn=check_score_goodness,
                                 threshold=1)
        self.judge.set_lm(dspy.LM('gemini/gemini-2.5-flash-lite', temperature=1))
        
        self.n_samples = n_samples
    
    async def acall(self, query: str) -> JokeIdea:
        joke_ideas = await asyncio.gather(*[
            self.query2idea.acall(query=query)
            for _ in range(self.n_samples)
        ])
        
        print(f'Generated Joke Ideas: \n{joke_ideas}')
        
        judge_score = self.judge(joke_idea=joke_ideas).joke_ratings
        print(f'Judge score for each: {judge_score}')
        
        best_idx = judge_score.index(1)
        selected = joke_ideas[best_idx]
        print(f'Selected: \n{selected}')
        
        return selected

class JokeGenerator(dspy.Module):
    def __init__(self, n_reflections=3):
        self.idea2joke = dspy.ChainOfThought(IdeaToJoke)
        self.idea2joke.set_lm(dspy.LM('gemini/gemini-2.5-flash-lite', temperature=0.7))
        self.n_reflections = n_reflections
    
    async def acall(self, joke_idea: JokeIdea):
        joke = None
        for _ in range(self.n_reflections):
            joke = self.idea2joke(joke_idea=joke_idea, joke_draft=joke)
            print(joke)
        return joke.joke if joke is not None else ''

# %%
dspy.configure(lm=dspy.LM('gemini/gemini-2.5-flash-lite'), temperature=1)
dspy.configure_cache(enable_disk_cache=False, enable_memory_cache=False)

idea_gen = IdeaGenerator(n_samples=3)
joke_gen = JokeGenerator(n_reflections=2)

idea = await idea_gen.acall(query='OpenAI')
joke = await joke_gen.acall(joke_idea=idea)
# Out:
# Generated Joke Ideas:
# [Prediction(
#     trajectory={'thought_0': 'I need to come up with a joke about OpenAI. The user\'s query is "OpenAI". I should fetch some recent news about OpenAI to get some ideas for a joke. The `fetch_recent_news` tool seems appropriate for this. I\'ll use "OpenAI" as the query.', 'tool_name_0': 'fetch_recent_news', 'tool_args_0': {'query': 'OpenAI'}, 'observation_0': ['# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk\'s lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".', "# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.", '# \'This case is going to trial\': Judge rejects Sam Altman\'s efforts to toss Elon Musk\'s OpenAI lawsuit. * A California judge said that Elon Musk\'s lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman\'s lawyers\' last-ditch efforts to end Musk\'s case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk\'s ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company\'s structure.', '# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routi ...
#     reasoning='The user wants a joke about OpenAI. I have fetched recent news about OpenAI, and there are a few interesting angles:\n1. Elon Musk\'s lawsuit against OpenAI for allegedly violating its founding mission and becoming too profit-oriented.\n2. OpenAI reportedly developing a new voice AI model and potentially new voice-based devices, aiming for mass adoption.\n3. OpenAI unveiling ChatGPT Health, a feature to review test results, diets, etc., indicating a push into the healthcare sector.\n\nThe lawsuit angle offers a clear conflict and a public figure (Elon Musk) which can be good for a joke. The voice AI development and the healthcare push are also interesting. I think the lawsuit angle has the most potential for a setup and punchline based on contradiction. The contradiction here is between OpenAI\'s original "open" and "non-profit" mission and its current profit-driven actions, as alleged by Musk.\n\nLet\'s focus on the Elon Musk lawsuit angle. The setup can introduce OpenAI and its founding principles, and the punchline can highlight the contradiction with its current practices as seen by Musk, leading to the lawsuit.',
#     joke_idea=JokeIdea(setup='OpenAI was founded with the mission to ensure that artificial general intelligence benefits all of humanity. It was supposed to be non-profit!', contradiction="But now Elon Musk is suing them for becoming too profit-driven, saying they've lost their way.", punchline="So, essentially, OpenAI's biggest breakthrough wasn't AI... it was figuring out how to turn 'Open' into 'Own More Money'.")
# ), Prediction(
#     trajectory={'thought_0': "I need to come up with a joke about OpenAI. To do that, I should first gather some recent news or interesting facts about OpenAI. The `fetch_recent_news` tool seems appropriate for this. I'll start by searching for general news about OpenAI.", 'tool_name_0': 'fetch_recent_news', 'tool_args_0': {'query': 'OpenAI'}, 'observation_0': ['# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk\'s lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".', "# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.", '# \'This case is going to trial\': Judge rejects Sam Altman\'s efforts to toss Elon Musk\'s OpenAI lawsuit. * A California judge said that Elon Musk\'s lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman\'s lawyers\' last-ditch efforts to end Musk\'s case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk\'s ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company\'s structure.', '# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout rou ...
#     reasoning="The user wants a joke about OpenAI. I have gathered some recent news about OpenAI, including Elon Musk's lawsuit regarding its non-profit status, and the development of new voice AI models and ChatGPT Health. The lawsuit seems like a good angle for a joke due to the public nature of the dispute and the prominent figures involved.",
#     joke_idea=JokeIdea(setup='Why did Elon Musk sue OpenAI?', contradiction='He claimed they violated their founding mission by becoming too for-profit.', punchline="He wanted to remind them that AI stands for 'Also, I'm investing in my own AI company that competes with yours!'")
# ), Prediction(
#     trajectory={'thought_0': 'I need to find some recent news about OpenAI to generate a joke. The `fetch_recent_news` tool seems appropriate for this. I\'ll use "OpenAI" as the query.', 'tool_name_0': 'fetch_recent_news', 'tool_args_0': {'query': 'OpenAI'}, 'observation_0': ['# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk\'s lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".', "# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.", '# \'This case is going to trial\': Judge rejects Sam Altman\'s efforts to toss Elon Musk\'s OpenAI lawsuit. * A California judge said that Elon Musk\'s lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman\'s lawyers\' last-ditch efforts to end Musk\'s case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk\'s ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company\'s structure.', '# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routines — marking the company’s biggest push yet into the healthcare sector. OpenAI unvei ...
#     reasoning='The user is asking for a joke about OpenAI. I have gathered some recent news about OpenAI. The news mentions Elon Musk suing OpenAI for changing its mission, OpenAI developing a new voice AI model, and OpenAI launching ChatGPT Health. The lawsuit aspect seems like a good hook for a joke, as it involves a public figure and a core dispute about the company\'s identity. I can play on the idea of OpenAI being a "for-profit" entity now, contrasting it with its original mission. The lawsuit angle with Elon Musk provides a good setup and a clear contradiction.',
#     joke_idea=JokeIdea(setup="Elon Musk is suing OpenAI, claiming they've abandoned their original mission.", contradiction="He says they've become too focused on profit, which is ironic because he's trying to make them pay him.", punchline="So, he's suing them for being too much like a business, but his legal strategy is all about the business of suing!")
# )]
# Judge score for each: [1, 3, 2]
# Selected:
# Prediction(
#     trajectory={'thought_0': 'I need to come up with a joke about OpenAI. The user\'s query is "OpenAI". I should fetch some recent news about OpenAI to get some ideas for a joke. The `fetch_recent_news` tool seems appropriate for this. I\'ll use "OpenAI" as the query.', 'tool_name_0': 'fetch_recent_news', 'tool_args_0': {'query': 'OpenAI'}, 'observation_0': ['# Musk lawsuit over OpenAI for-profit conversion can head to trial, US judge says. * Musk claims OpenAI violated its founding mission in restructuring to a for-profit entity. * OpenAI denies claims, calls Musk\'s lawsuit baseless. * Musk was a co-founder of OpenAI, now runs a rival AI company. WASHINGTON, Jan 7 (Reuters) - Billionaire entrepreneur Elon Musk persuaded a judge on Wednesday to allow a jury trial on his allegations that ChatGPT maker OpenAI violated its founding mission in its high-profile restructuring to a for-profit entity. Musk was a cofounder of OpenAI in 2015 but left in 2018 and now runs an AI company that competes with it. OpenAI in a statement after the hearing said: "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial.". OpenAI, Altman and Brockman have denied the claims, and they called Musk "a frustrated commercial competitor seeking to slow down a mission-driven market leader.".', "# OpenAI is reportedly developing a new voice AI model for voice-based AI devices. OpenAI, a major AI company, is betting big on voice AI, integrating its engineering, product, and research teams to revamp its voice AI, **The Information** reported. OpenAI's voice AI efforts are said to be in preparation for the company's upcoming voice device. **Google is developing an AI feature that will summarize search results in a radio-like voice - GIGAZINE**. OpenAI is also reportedly focusing on developing voice AI for voice AI devices. OpenAI is developing new voice models by integrating its engineering, product, and research teams, led by former Character.AI researcher Kundan Kumar, The Information reported. OpenAI is reportedly planning to develop glasses-type and screenless smart speakers, and has already created prototypes of the AI devices it is developing, **aiming to ship 100 million units in the fastest time in history** . * Microsoft is reportedly developing its own large-scale language model 'MAI-1,' which could compete with Google, OpenAI, and Anthropic's AI models.", '# \'This case is going to trial\': Judge rejects Sam Altman\'s efforts to toss Elon Musk\'s OpenAI lawsuit. * A California judge said that Elon Musk\'s lawsuit against OpenAI and Sam Altman can proceed to trial. During a hearing on Wednesday, a California judge said she plans to reject Altman\'s lawyers\' last-ditch efforts to end Musk\'s case against OpenAI and its CEO. In his lawsuit filed in 2024, Musk accused OpenAI of misleading him in its decision to abandon its original nonprofit mission and structure in favor of a profit-oriented model, including through its partnership with Microsoft. "Mr Musk\'s lawsuit continues to be baseless and a part of his ongoing pattern of harassment, and we look forward to demonstrating this at trial," a spokesperson for OpenAI told Business Insider. Musk has filed multiple lawsuits against OpenAI. At the time, an OpenAI spokesperson told Business that the lawsuit is "the latest chapter in Mr. Musk\'s ongoing harassment.". Since, Musk has repeatedly criticized Altman and OpenAI, including the company\'s structure.', '# OpenAI unveils ChatGPT Health to review test results, diets. * OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results. * More than 200 million people already ask ChatGPT health and wellness questions every week, according to the company. OpenAI is introducing a new feature in ChatGPT that will allow users to analyze medical test results, prepare for doctors appointments and seek guidance on diets and workout routi ...
#     reasoning='The user wants a joke about OpenAI. I have fetched recent news about OpenAI, and there are a few interesting angles:\n1. Elon Musk\'s lawsuit against OpenAI for allegedly violating its founding mission and becoming too profit-oriented.\n2. OpenAI reportedly developing a new voice AI model and potentially new voice-based devices, aiming for mass adoption.\n3. OpenAI unveiling ChatGPT Health, a feature to review test results, diets, etc., indicating a push into the healthcare sector.\n\nThe lawsuit angle offers a clear conflict and a public figure (Elon Musk) which can be good for a joke. The voice AI development and the healthcare push are also interesting. I think the lawsuit angle has the most potential for a setup and punchline based on contradiction. The contradiction here is between OpenAI\'s original "open" and "non-profit" mission and its current profit-driven actions, as alleged by Musk.\n\nLet\'s focus on the Elon Musk lawsuit angle. The setup can introduce OpenAI and its founding principles, and the punchline can highlight the contradiction with its current practices as seen by Musk, leading to the lawsuit.',
#     joke_idea=JokeIdea(setup='OpenAI was founded with the mission to ensure that artificial general intelligence benefits all of humanity. It was supposed to be non-profit!', contradiction="But now Elon Musk is suing them for becoming too profit-driven, saying they've lost their way.", punchline="So, essentially, OpenAI's biggest breakthrough wasn't AI... it was figuring out how to turn 'Open' into 'Own More Money'.")
# )
# Prediction(
#     reasoning='The joke idea is about OpenAI\'s founding mission versus its current profit-driven model, as highlighted by Elon Musk\'s lawsuit. The draft is `None`, so I need to create a joke from scratch based on the `joke_idea`. I\'ll lean into the contrast between "OpenAI" and "profit," and the irony of a lawsuit from a co-founder. I\'ll frame it as a story about their mission and then hit with the punchline about their current business model.',
#     joke='So, you know OpenAI, right? They started out with this grand, noble mission: "Let\'s make sure artificial general intelligence benefits *all* of humanity." Sounds pretty altruistic, like they were going to share their super-intelligent AI with everyone, like a digital Robin Hood. It was supposed to be non-profit, all about the greater good.\n\nWell, fast forward to today, and who\'s suing them? None other than Elon Musk, one of their original co-founders! He\'s saying they\'ve totally lost their way, gone too commercial, and become way too profit-driven.\n\nIt\'s kind of ironic, isn\'t it? OpenAI\'s biggest breakthrough wasn\'t some revolutionary AI model... it was figuring out how to turn "Open" into "Own More Money."'
# )
# Prediction(
#     reasoning='The user wants a joke about OpenAI, specifically focusing on the contradiction between its founding mission and its current profit-driven model, as highlighted by Elon Musk\'s lawsuit. The provided draft is a good start, but it could be punchier and more conversational, fitting the persona of a comedian. I\'ll refine the setup to be more engaging and make the punchline land a bit harder by emphasizing the "Open" to "Own" transformation.',
#     joke='Alright, so you know OpenAI, right? These guys started with this super noble, heartwarming mission statement: "Let\'s make sure artificial general intelligence benefits *all* of humanity." Like, they were gonna be the AI fairy godmothers, sprinkling smartness on everyone. And get this – it was supposed to be *non-profit*! All about the greater good, sharing the AI wealth, you know?\n\nThen, plot twist! Who decides to sue them? Elon Musk! Yeah, one of the original architects of OpenAI. He\'s basically saying, "Hey! You guys have gone totally corporate! Where\'s the open source? Where\'s the humanity? All I see is dollar signs!"\n\nAnd you know what\'s hilarious? It turns out OpenAI\'s biggest, most earth-shattering innovation wasn\'t some mind-blowing AI... it was figuring out how to perfectly transform the word "Open" into "Own More Money."'
# )

# %%
print(joke)
# Out:
# Alright, so you know OpenAI, right? These guys started with this super noble, heartwarming mission statement: "Let's make sure artificial general intelligence benefits *all* of humanity." Like, they were gonna be the AI fairy godmothers, sprinkling smartness on everyone. And get this – it was supposed to be *non-profit*! All about the greater good, sharing the AI wealth, you know?
#
# Then, plot twist! Who decides to sue them? Elon Musk! Yeah, one of the original architects of OpenAI. He's basically saying, "Hey! You guys have gone totally corporate! Where's the open source? Where's the humanity? All I see is dollar signs!"
#
# And you know what's hilarious? It turns out OpenAI's biggest, most earth-shattering innovation wasn't some mind-blowing AI... it was figuring out how to perfectly transform the word "Open" into "Own More Money."
